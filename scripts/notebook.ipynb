# %%
import torch

PRECISION = 7
tolerance = float(f"1e-{PRECISION}")
torch.set_printoptions(precision=PRECISION)

state_0 = torch.load("state_0.pt")
state_1 = torch.load("state_1.pt")
state_ref_0 = torch.load("state_ref_0.pt")
state_ref_1 = torch.load("state_ref_1.pt")

# First check if state_ref_0 and state_ref_1 are the same
for epoch in state_ref_0.keys():
    for chunk in zip(state_ref_0[epoch].items(), state_ref_1[epoch].items()):
        chunk_state_ref_0, chunk_state_ref_1 = chunk
        name_state_ref_0, value_state_ref_0 = chunk_state_ref_0
        name_state_ref_1, value_state_ref_1 = chunk_state_ref_1

        value_state_ref_0 = value_state_ref_0.to(torch.device("cuda:0"))
        value_state_ref_1 = value_state_ref_1.to(torch.device("cuda:0"))

        try:
            torch.testing.assert_close(value_state_ref_0, value_state_ref_1, rtol=tolerance, atol=tolerance)
        except AssertionError as e:
            print(epoch)
            print(e)

print("state_ref_0 and state_ref_1 are the same")

for epoch in state_0.keys():

    for chunk in zip(state_0[epoch].items(), state_1[epoch].items(), state_ref_0[epoch].items()):
        print("================")
        chunk_state_0, chunk_state_1, chunk_state_ref_0 = chunk

        name_state_0, value_state_0 = chunk_state_0
        name_state_1, value_state_1 = chunk_state_1
        name_state_ref_0, value_state_ref_0 = chunk_state_ref_0
        
        value_state_0 = value_state_0.to(torch.device("cuda:0"))
        value_state_1 = value_state_1.to(torch.device("cuda:0"))
        value_state_ref_0 = value_state_ref_0.to(torch.device("cuda:0"))

        value_cat = torch.cat([value_state_0, value_state_1], dim=0)

        try:
            torch.testing.assert_close(value_cat, value_state_ref_0, rtol=tolerance, atol=tolerance)
            print(epoch, name_state_0, "OK")
        except AssertionError as e:
            print(epoch, name_state_0, "FAIL", "=>")
            print(e)
# Out:
# state_ref_0 and state_ref_1 are the same
# ================
# epoch_0 bias OK
# ================
# epoch_0 weight OK
# ================
# epoch_1 bias OK
# ================
# epoch_1 weight OK
# ================
# epoch_2 bias OK
# ================
# epoch_2 weight OK
# ================
# epoch_3 bias OK
# ================
# epoch_3 weight OK
# ================
# epoch_4 bias OK
# ================
# epoch_4 weight OK
# ================
# epoch_5 bias OK
# ================
# epoch_5 weight OK
# ================
# epoch_6 bias OK
# ================
# epoch_6 weight OK
# ================
# epoch_7 bias OK
# ================
# epoch_7 weight OK
# ================
# epoch_8 bias OK
# ================
# epoch_8 weight OK
# ================
# epoch_9 bias OK
# ================
# epoch_9 weight OK
# ================
# epoch_10 bias OK
# ================
# epoch_10 weight OK
# ================
# epoch_11 bias OK
# ================
# epoch_11 weight OK
# ================
# epoch_12 bias OK
# ================
# epoch_12 weight OK
# ================
# epoch_13 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 2 / 10 (20.0%)
# Greatest absolute difference: 1.9371509552001953e-07 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 5.6002700148383155e-06 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_13 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 1588 / 10240 (15.5%)
# Greatest absolute difference: 2.0116567611694336e-07 at index (4, 120) (up to 1e-07 allowed)
# Greatest relative difference: 7.654104592802469e-06 at index (7, 662) (up to 1e-07 allowed)
# ================
# epoch_14 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 4 / 10 (40.0%)
# Greatest absolute difference: 4.917383193969727e-07 at index (7,) (up to 1e-07 allowed)
# Greatest relative difference: 7.793527402100153e-06 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_14 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 2855 / 10240 (27.9%)
# Greatest absolute difference: 4.991888999938965e-07 at index (7, 111) (up to 1e-07 allowed)
# Greatest relative difference: 0.0007497598417103291 at index (6, 273) (up to 1e-07 allowed)
# ================
# epoch_15 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 5 / 10 (50.0%)
# Greatest absolute difference: 1.1026859283447266e-06 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 5.603754289040808e-06 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_15 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 4319 / 10240 (42.2%)
# Greatest absolute difference: 1.1324882507324219e-06 at index (4, 59) (up to 1e-07 allowed)
# Greatest relative difference: 0.0002582807501312345 at index (7, 367) (up to 1e-07 allowed)
# ================
# epoch_16 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 5 / 10 (50.0%)
# Greatest absolute difference: 1.4603137969970703e-06 at index (7,) (up to 1e-07 allowed)
# Greatest relative difference: 2.6835312382900156e-05 at index (8,) (up to 1e-07 allowed)
# ================
# epoch_16 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 4417 / 10240 (43.1%)
# Greatest absolute difference: 1.519918441772461e-06 at index (7, 476) (up to 1e-07 allowed)
# Greatest relative difference: 0.0006231569568626583 at index (8, 497) (up to 1e-07 allowed)
# ================
# epoch_17 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 4 / 10 (40.0%)
# Greatest absolute difference: 2.7567148208618164e-06 at index (1,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0001147318325820379 at index (2,) (up to 1e-07 allowed)
# ================
# epoch_17 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 4042 / 10240 (39.5%)
# Greatest absolute difference: 2.771615982055664e-06 at index (1, 42) (up to 1e-07 allowed)
# Greatest relative difference: 0.050212129950523376 at index (2, 729) (up to 1e-07 allowed)
# ================
# epoch_18 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 6 / 10 (60.0%)
# Greatest absolute difference: 2.041459083557129e-06 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 6.796740490244702e-05 at index (4,) (up to 1e-07 allowed)
# ================
# epoch_18 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 5781 / 10240 (56.5%)
# Greatest absolute difference: 2.0507723093032837e-06 at index (4, 164) (up to 1e-07 allowed)
# Greatest relative difference: 0.16619478166103363 at index (2, 436) (up to 1e-07 allowed)
# ================
# epoch_19 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8 / 10 (80.0%)
# Greatest absolute difference: 9.387731552124023e-06 at index (1,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0005320287891663611 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_19 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 7645 / 10240 (74.7%)
# Greatest absolute difference: 9.402632713317871e-06 at index (1, 228) (up to 1e-07 allowed)
# Greatest relative difference: 0.24085089564323425 at index (6, 529) (up to 1e-07 allowed)
# ================
# epoch_20 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 7 / 10 (70.0%)
# Greatest absolute difference: 2.3692846298217773e-06 at index (2,) (up to 1e-07 allowed)
# Greatest relative difference: 0.00017342710634693503 at index (9,) (up to 1e-07 allowed)
# ================
# epoch_20 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 6889 / 10240 (67.3%)
# Greatest absolute difference: 2.3730099201202393e-06 at index (2, 950) (up to 1e-07 allowed)
# Greatest relative difference: 0.025005249306559563 at index (9, 567) (up to 1e-07 allowed)
# ================
# epoch_21 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9 / 10 (90.0%)
# Greatest absolute difference: 2.0407140254974365e-05 at index (1,) (up to 1e-07 allowed)
# Greatest relative difference: 0.00115914735943079 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_21 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9040 / 10240 (88.3%)
# Greatest absolute difference: 2.041459083557129e-05 at index (1, 50) (up to 1e-07 allowed)
# Greatest relative difference: 0.14590893685817719 at index (8, 244) (up to 1e-07 allowed)
# ================
# epoch_22 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9 / 10 (90.0%)
# Greatest absolute difference: 1.8786638975143433e-05 at index (1,) (up to 1e-07 allowed)
# Greatest relative difference: 0.006406506057828665 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_22 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9083 / 10240 (88.7%)
# Greatest absolute difference: 1.87847763299942e-05 at index (1, 76) (up to 1e-07 allowed)
# Greatest relative difference: 0.8200457692146301 at index (7, 535) (up to 1e-07 allowed)
# ================
# epoch_23 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 7.517635822296143e-06 at index (8,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0013373778201639652 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_23 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9796 / 10240 (95.7%)
# Greatest absolute difference: 8.471310138702393e-06 at index (9, 845) (up to 1e-07 allowed)
# Greatest relative difference: 0.2436462938785553 at index (1, 877) (up to 1e-07 allowed)
# ================
# epoch_24 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8 / 10 (80.0%)
# Greatest absolute difference: 4.447996616363525e-06 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.000121565222798381 at index (5,) (up to 1e-07 allowed)
# ================
# epoch_24 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8258 / 10240 (80.6%)
# Greatest absolute difference: 4.623085260391235e-06 at index (5, 614) (up to 1e-07 allowed)
# Greatest relative difference: 0.06403031200170517 at index (2, 690) (up to 1e-07 allowed)
# ================
# epoch_25 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9 / 10 (90.0%)
# Greatest absolute difference: 6.310641765594482e-06 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.00013629179738927633 at index (5,) (up to 1e-07 allowed)
# ================
# epoch_25 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8907 / 10240 (87.0%)
# Greatest absolute difference: 6.314367055892944e-06 at index (5, 0) (up to 1e-07 allowed)
# Greatest relative difference: 0.03319355845451355 at index (6, 534) (up to 1e-07 allowed)
# ================
# epoch_26 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 2.4303793907165527e-05 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.003961935173720121 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_26 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9991 / 10240 (97.6%)
# Greatest absolute difference: 2.4333596229553223e-05 at index (5, 87) (up to 1e-07 allowed)
# Greatest relative difference: 0.5659732818603516 at index (1, 329) (up to 1e-07 allowed)
# ================
# epoch_27 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8 / 10 (80.0%)
# Greatest absolute difference: 2.8535723686218262e-05 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.00034981529461219907 at index (9,) (up to 1e-07 allowed)
# ================
# epoch_27 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8318 / 10240 (81.2%)
# Greatest absolute difference: 2.855062484741211e-05 at index (9, 137) (up to 1e-07 allowed)
# Greatest relative difference: 0.12454842031002045 at index (8, 657) (up to 1e-07 allowed)
# ================
# epoch_28 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 1.5594065189361572e-05 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0005877848598174751 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_28 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10122 / 10240 (98.8%)
# Greatest absolute difference: 1.5616416931152344e-05 at index (5, 733) (up to 1e-07 allowed)
# Greatest relative difference: 0.2263665646314621 at index (3, 406) (up to 1e-07 allowed)
# ================
# epoch_29 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 7.095932960510254e-05 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.02635123021900654 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_29 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10179 / 10240 (99.4%)
# Greatest absolute difference: 7.098913192749023e-05 at index (9, 122) (up to 1e-07 allowed)
# Greatest relative difference: 54.9935188293457 at index (1, 471) (up to 1e-07 allowed)
# ================
# epoch_30 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9 / 10 (90.0%)
# Greatest absolute difference: 3.866851329803467e-05 at index (7,) (up to 1e-07 allowed)
# Greatest relative difference: 0.02927929349243641 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_30 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9118 / 10240 (89.0%)
# Greatest absolute difference: 3.8683414459228516e-05 at index (7, 86) (up to 1e-07 allowed)
# Greatest relative difference: 1.921060562133789 at index (0, 819) (up to 1e-07 allowed)
# ================
# epoch_31 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 5.350494757294655e-05 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 0.007163430564105511 at index (4,) (up to 1e-07 allowed)
# ================
# epoch_31 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10193 / 10240 (99.5%)
# Greatest absolute difference: 5.350681021809578e-05 at index (4, 706) (up to 1e-07 allowed)
# Greatest relative difference: 0.5450161695480347 at index (5, 307) (up to 1e-07 allowed)
# ================
# epoch_32 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9 / 10 (90.0%)
# Greatest absolute difference: 4.357472062110901e-05 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 0.002776357578113675 at index (4,) (up to 1e-07 allowed)
# ================
# epoch_32 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 9057 / 10240 (88.4%)
# Greatest absolute difference: 4.357472062110901e-05 at index (4, 53) (up to 1e-07 allowed)
# Greatest relative difference: 4.070110321044922 at index (1, 143) (up to 1e-07 allowed)
# ================
# epoch_33 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 4.5282766222953796e-05 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0045115468092262745 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_33 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10083 / 10240 (98.5%)
# Greatest absolute difference: 4.6115368604660034e-05 at index (4, 283) (up to 1e-07 allowed)
# Greatest relative difference: 4.5278730392456055 at index (8, 360) (up to 1e-07 allowed)
# ================
# epoch_34 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 6.850063800811768e-05 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.0047021349892020226 at index (5,) (up to 1e-07 allowed)
# ================
# epoch_34 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10159 / 10240 (99.2%)
# Greatest absolute difference: 6.853044033050537e-05 at index (9, 47) (up to 1e-07 allowed)
# Greatest relative difference: 2.113442897796631 at index (1, 781) (up to 1e-07 allowed)
# ================
# epoch_35 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8 / 10 (80.0%)
# Greatest absolute difference: 3.41758131980896e-05 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.005639873445034027 at index (5,) (up to 1e-07 allowed)
# ================
# epoch_35 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 8687 / 10240 (84.8%)
# Greatest absolute difference: 3.4176744520664215e-05 at index (5, 419) (up to 1e-07 allowed)
# Greatest relative difference: 0.6878445744514465 at index (5, 340) (up to 1e-07 allowed)
# ================
# epoch_36 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 9.226985275745392e-05 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.07583403587341309 at index (8,) (up to 1e-07 allowed)
# ================
# epoch_36 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10200 / 10240 (99.6%)
# Greatest absolute difference: 9.227357804775238e-05 at index (9, 107) (up to 1e-07 allowed)
# Greatest relative difference: 13.114531517028809 at index (8, 804) (up to 1e-07 allowed)
# ================
# epoch_37 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 9.394530206918716e-05 at index (8,) (up to 1e-07 allowed)
# Greatest relative difference: 0.026572110131382942 at index (9,) (up to 1e-07 allowed)
# ================
# epoch_37 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10151 / 10240 (99.1%)
# Greatest absolute difference: 9.394343942403793e-05 at index (8, 104) (up to 1e-07 allowed)
# Greatest relative difference: 20.673664093017578 at index (9, 791) (up to 1e-07 allowed)
# ================
# epoch_38 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.00011705607175827026 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.26137328147888184 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_38 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10217 / 10240 (99.8%)
# Greatest absolute difference: 0.0001178160309791565 at index (5, 948) (up to 1e-07 allowed)
# Greatest relative difference: 180.4366912841797 at index (7, 341) (up to 1e-07 allowed)
# ================
# epoch_39 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.00019765645265579224 at index (8,) (up to 1e-07 allowed)
# Greatest relative difference: 0.03418634831905365 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_39 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10218 / 10240 (99.8%)
# Greatest absolute difference: 0.00019766390323638916 at index (8, 75) (up to 1e-07 allowed)
# Greatest relative difference: 25.308401107788086 at index (7, 974) (up to 1e-07 allowed)
# ================
# epoch_40 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.00032363831996917725 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.02480860985815525 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_40 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10232 / 10240 (99.9%)
# Greatest absolute difference: 0.0003239363431930542 at index (5, 980) (up to 1e-07 allowed)
# Greatest relative difference: 2.688667058944702 at index (7, 945) (up to 1e-07 allowed)
# ================
# epoch_41 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.000262528657913208 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.07130689918994904 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_41 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10226 / 10240 (99.9%)
# Greatest absolute difference: 0.00026288628578186035 at index (9, 902) (up to 1e-07 allowed)
# Greatest relative difference: 14.99068832397461 at index (7, 519) (up to 1e-07 allowed)
# ================
# epoch_42 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0005187839269638062 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.01824224554002285 at index (1,) (up to 1e-07 allowed)
# ================
# epoch_42 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10237 / 10240 (100.0%)
# Greatest absolute difference: 0.0005187876522541046 at index (9, 51) (up to 1e-07 allowed)
# Greatest relative difference: 20.99165153503418 at index (2, 405) (up to 1e-07 allowed)
# ================
# epoch_43 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0006172098219394684 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.04200967028737068 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_43 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10227 / 10240 (99.9%)
# Greatest absolute difference: 0.0006172135472297668 at index (9, 76) (up to 1e-07 allowed)
# Greatest relative difference: 2.99861478805542 at index (6, 790) (up to 1e-07 allowed)
# ================
# epoch_44 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0013634786009788513 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.9608714580535889 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_44 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.0013636276125907898 at index (9, 260) (up to 1e-07 allowed)
# Greatest relative difference: 8.375237464904785 at index (0, 413) (up to 1e-07 allowed)
# ================
# epoch_45 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0005022063851356506 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.14032365381717682 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_45 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10235 / 10240 (100.0%)
# Greatest absolute difference: 0.0005022063851356506 at index (5, 75) (up to 1e-07 allowed)
# Greatest relative difference: 10.13795280456543 at index (6, 362) (up to 1e-07 allowed)
# ================
# epoch_46 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0041803717613220215 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.05444725975394249 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_46 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10237 / 10240 (100.0%)
# Greatest absolute difference: 0.0041803643107414246 at index (9, 87) (up to 1e-07 allowed)
# Greatest relative difference: 21.107105255126953 at index (3, 812) (up to 1e-07 allowed)
# ================
# epoch_47 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.001723308116197586 at index (7,) (up to 1e-07 allowed)
# Greatest relative difference: 0.16388486325740814 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_47 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10239 / 10240 (100.0%)
# Greatest absolute difference: 0.0017238259315490723 at index (7, 284) (up to 1e-07 allowed)
# Greatest relative difference: 65.7093505859375 at index (3, 777) (up to 1e-07 allowed)
# ================
# epoch_48 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.01032169908285141 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 3.460393190383911 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_48 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10240 / 10240 (100.0%)
# Greatest absolute difference: 0.010321702808141708 at index (9, 0) (up to 1e-07 allowed)
# Greatest relative difference: 5367.654296875 at index (6, 236) (up to 1e-07 allowed)
# ================
# epoch_49 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.006374046206474304 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.23103387653827667 at index (7,) (up to 1e-07 allowed)
# ================
# epoch_49 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10234 / 10240 (99.9%)
# Greatest absolute difference: 0.006374061107635498 at index (9, 116) (up to 1e-07 allowed)
# Greatest relative difference: 32.01536560058594 at index (4, 273) (up to 1e-07 allowed)
# ================
# epoch_50 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0021324828267097473 at index (4,) (up to 1e-07 allowed)
# Greatest relative difference: 0.10879538953304291 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_50 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.003063289914280176 at index (9, 272) (up to 1e-07 allowed)
# Greatest relative difference: 180.7064666748047 at index (0, 179) (up to 1e-07 allowed)
# ================
# epoch_51 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0016024485230445862 at index (3,) (up to 1e-07 allowed)
# Greatest relative difference: 0.22757822275161743 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_51 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10176 / 10240 (99.4%)
# Greatest absolute difference: 0.0016024503856897354 at index (3, 0) (up to 1e-07 allowed)
# Greatest relative difference: 57.49575424194336 at index (0, 431) (up to 1e-07 allowed)
# ================
# epoch_52 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0015392228960990906 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.07593069970607758 at index (9,) (up to 1e-07 allowed)
# ================
# epoch_52 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.0015767067670822144 at index (5, 976) (up to 1e-07 allowed)
# Greatest relative difference: 92.49640655517578 at index (6, 498) (up to 1e-07 allowed)
# ================
# epoch_53 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0004092976450920105 at index (3,) (up to 1e-07 allowed)
# Greatest relative difference: 0.23544564843177795 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_53 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10235 / 10240 (100.0%)
# Greatest absolute difference: 0.00040930137038230896 at index (3, 77) (up to 1e-07 allowed)
# Greatest relative difference: 45.102386474609375 at index (6, 604) (up to 1e-07 allowed)
# ================
# epoch_54 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0033303946256637573 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.38332197070121765 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_54 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.0033304020762443542 at index (5, 42) (up to 1e-07 allowed)
# Greatest relative difference: 25.971107482910156 at index (6, 189) (up to 1e-07 allowed)
# ================
# epoch_55 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0024505481123924255 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.07978971302509308 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_55 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10234 / 10240 (99.9%)
# Greatest absolute difference: 0.0024505555629730225 at index (5, 106) (up to 1e-07 allowed)
# Greatest relative difference: 307.03668212890625 at index (0, 660) (up to 1e-07 allowed)
# ================
# epoch_56 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0013118274509906769 at index (3,) (up to 1e-07 allowed)
# Greatest relative difference: 0.03568557649850845 at index (2,) (up to 1e-07 allowed)
# ================
# epoch_56 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.0013118349015712738 at index (3, 81) (up to 1e-07 allowed)
# Greatest relative difference: 10.183506965637207 at index (7, 785) (up to 1e-07 allowed)
# ================
# epoch_57 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0005914866924285889 at index (5,) (up to 1e-07 allowed)
# Greatest relative difference: 0.1280694454908371 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_57 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10239 / 10240 (100.0%)
# Greatest absolute difference: 0.0005914792418479919 at index (5, 388) (up to 1e-07 allowed)
# Greatest relative difference: 136.08285522460938 at index (6, 314) (up to 1e-07 allowed)
# ================
# epoch_58 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0018130689859390259 at index (9,) (up to 1e-07 allowed)
# Greatest relative difference: 0.35775890946388245 at index (6,) (up to 1e-07 allowed)
# ================
# epoch_58 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10238 / 10240 (100.0%)
# Greatest absolute difference: 0.0018130764365196228 at index (9, 42) (up to 1e-07 allowed)
# Greatest relative difference: 236.17640686035156 at index (6, 777) (up to 1e-07 allowed)
# ================
# epoch_59 bias FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10 / 10 (100.0%)
# Greatest absolute difference: 0.0010805577039718628 at index (7,) (up to 1e-07 allowed)
# Greatest relative difference: 0.08117539435625076 at index (0,) (up to 1e-07 allowed)
# ================
# epoch_59 weight FAIL =>
# Tensor-likes are not close!
#
# Mismatched elements: 10239 / 10240 (100.0%)
# Greatest absolute difference: 0.0010961592197418213 at index (7, 284) (up to 1e-07 allowed)
# Greatest relative difference: 21.190101623535156 at index (0, 472) (up to 1e-07 allowed)
